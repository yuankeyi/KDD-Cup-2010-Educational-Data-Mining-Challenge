# %% [markdown]
# **A data science experiment using data from the KDD 2010 Educational Data Mining Challenge**
#
# The aim of this IPython Notebook is to give you a sense of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import random

# %%
# Get the data: Algebra 2005-2006
#train_filepath = 'algebra_2005_2006_train.txt'
#traindata = pd.read_table(train_filepath)
traindata = pd.read_csv('train.csv',sep = '\t')
testdata = pd.read_csv('test.csv',sep = '\t')

# %% [markdown]
# Some more information the data format can be found on the [challenge website](https://pslcdatashop.web.cmu.edu/KDDCup/rules_data_format.jsp)

# %%
traindata.columns
# Out:
# Index(['Row', 'Anon Student Id', 'Problem Hierarchy', 'Problem Name',
#        'Problem View', 'Step Name', 'Step Start Time',
#        'First Transaction Time', 'Correct Transaction Time', 'Step End Time',
#        'Step Duration (sec)', 'Correct Step Duration (sec)',
#        'Error Step Duration (sec)', 'Correct First Attempt', 'Incorrects',
#        'Hints', 'Corrects', 'KC(Default)', 'Opportunity(Default)'],
#       dtype='object')

# %%
# Inspect some of the training data
traindata.head(n=105)
# Out:
#        Row Anon Student Id                Problem Hierarchy  Problem Name  \
# 0     9938      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 1     9939      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 2     9940      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 3     9941      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 4     9942      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 5     9943      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 6     9944      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 7     9945      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 8     9946      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 9     9947      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 10    9948      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 11    9949      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP04
# 12    9950      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 13    9951      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 14    9952      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 15    9953      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 16    9954      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 17    9955      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 18    9956      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 19    9957      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 20    9958      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 21    9959      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 22    9960      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 23    9961      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 24    9962      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP07
# 25    9963      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP08
# 26    9964      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP08
# 27    9965      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP08
# 28    9966      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP08
# 29    9967      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP08
# ..     ...             ...                              ...           ...
# 75   10013      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP12
# 76   10014      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP12
# 77   10015      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP12
# 78   10016      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP12
# 79   10017      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP12
# 80   10018      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 81   10019      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 82   10020      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 83   10021      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 84   10022      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 85   10023      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 86   10024      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 87   10025      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 88   10026      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 89   10027      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 90   10028      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 91   10029      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP02
# 92   10030      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 93   10031      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 94   10032      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 95   10033      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 96   10034      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 97   10035      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 98   10036      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 99   10037      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 100  10038      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1        PROP01
# 101  10100      52vEY7f17k  Unit CTA1_06, Section CTA1_06-1  LDEMO_4QGRPH
# 102  10101      52vEY7f17k  Unit CTA1_06, Section CTA1_06-1  LDEMO_4QGRPH
# 103  10102      52vEY7f17k  Unit CTA1_06, Section CTA1_06-1  LDEMO_4QGRPH
# 104  10103      52vEY7f17k  Unit CTA1_06, Section CTA1_06-1  LDEMO_4QGRPH
#
#      Problem View        Step Name        Step Start Time  \
# 0               1             R1C1  2005-09-09 12:23:34.0
# 1               1             R1C2  2005-09-09 12:24:07.0
# 2               1             R3C1  2005-09-09 12:24:22.0
# 3               1             R3C2  2005-09-09 12:25:40.0
# 4               1             R4C1  2005-09-09 12:27:24.0
# 5               1             R5C1  2005-09-09 12:27:30.0
# 6               1             R6C1  2005-09-09 12:27:41.0
# 7               1             R7C2  2005-09-09 12:28:50.0
# 8               1   ValidEquations  2005-09-09 12:31:39.0
# 9               1    7/10*X = 1400  2005-09-09 12:31:52.0
# 11          1  Using small numbers~~Find X, Simple~~Using dif...
# 12          1                                                NaN
# 13          1                                                NaN
# 14          1                                    Define Variable
# 15          1  Using small numbers~~Write expression, positiv...
# 16          0  Find Y, Simple~~Using small numbers~~Using dif...
# 17          1                                   Entering a given
# 18          1                                   Entering a given
# 19          1                                   Entering a given
# 20          1                                   Entering a given
# 21          2                                                NaN
# 22          1                                                NaN
# 23          1                                                NaN
# 24          1  Using small numbers~~Find X, Simple~~Using dif...
# 25          1                                                NaN
# 26          1                                                NaN
# 27          1                                    Define Variable
# 28          1  Using small numbers~~Write expression, positiv...
# 29          1                                   Entering a given
# ..        ...                                                ...
# 75          1  [SkillRule: Eliminate Parens; {CLT nested; CLT...
# 76          1  [SkillRule: Remove positive coefficient; {ax/b...
# 77          1  Using small numbers~~Find X, Simple~~Using dif...
# 78          1                                   Entering a given
# 79          1                                   Entering a given
# 80          1                                                NaN
# 81          1                                                NaN
# 82          1                                    Define Variable
# 83          1  Using small numbers~~Write expression, positiv...
# 84          1                                   Entering a given
# 85          1                                   Entering a given
# 86          1                                   Entering a given
# 87          1                                   Entering a given
# 88          2                                                NaN
# 89          1                                                NaN
# 90          1  [SkillRule: Remove positive coefficient; {ax/b...
# 91          1  Using small numbers~~Find X, Simple~~Using dif...
# 92          1                                                NaN
# 93          1                                                NaN
# 94          1                                    Define Variable
# 95          1  Using difficult numbers~~Using small numbers~~...
# 96          1                                   Entering a given
# 97          1                                   Entering a given
# 98          1                                   Entering a given
# 99          1                                   Entering a given
# 100         2                                                NaN
# 101         1                                                NaN
# 102         1                                                NaN
# 103         1                                  Identifying units
# 104         1                                    Define Variable
#
#     Opportunity(Default)
# 0                    NaN
# 1                    NaN
# 2                      1
# 3                1~~1~~1
# 4                      1
# 5                      2
# 6                      3
# 7                      4
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11               2~~1~~2
# 12                   NaN
# 13                   NaN
# 14                     2
# 15               3~~2~~3
# 16               1~~4~~4
# 17                     5
# 18                     6
# 19                     7
# 20                     8
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24               5~~2~~5
# 25                   NaN
# 26                   NaN
# 27                     3
# 28               6~~3~~6
# 29                     9
# ..                   ...
# 75                  1~~4
# 76                  4~~5
# 77             18~~7~~18
# 78                    22
# 79                    23
# 80                   NaN
# 81                   NaN
# 82                     7
# 83             19~~7~~19
# 84                    24
# 85                    25
# 86                    26
# 87                    27
# 88                   NaN
# 89                   NaN
# 90                  5~~6
# 91             20~~8~~20
# 92                   NaN
# 93                   NaN
# 94                     8
# 95             21~~21~~8
# 96                    28
# 97                    29
# 98                    30
# 99                    31
# 100                  NaN
# 101                  NaN
# 102                  NaN
# 103                    7
# 104                   13
#
# [105 rows x 19 columns]

# %%
# Inspect some of the training data
testdata.head(n=5)
# Out:
#      Row Anon Student Id                Problem Hierarchy Problem Name  \
# 0  10039      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP01
# 1  10482      52vEY7f17k  Unit CTA1_06, Section CTA1_06-3        FOR05
# 2  11024      52vEY7f17k      Unit ES_03, Section ES_03-6         EG52
# 3  11476      52vEY7f17k  Unit CTA1_08, Section CTA1_08-3       REAL10
# 4  11948      52vEY7f17k     Unit ES_04, Section ES_04-12         EG58
#
#    Problem View        Step Name  Step Start Time  First Transaction Time  \
# 0             1     2/300*X = 10              NaN                     NaN
# 1             1           xScale              NaN                     NaN
# 2             1  2.9 = -2x+3.7+x              NaN                     NaN
# 3             1           yScale              NaN                     NaN
# 4             7              xR2              NaN                     NaN
#
#    Correct Transaction Time  Step End Time  Step Duration (sec)  \
# 0                       NaN            NaN                  NaN
# 1                       NaN            NaN                  NaN
# 2                       NaN            NaN                  NaN
# 3                       NaN            NaN                  NaN
# 4                       NaN            NaN                  NaN
#
#    Correct Step Duration (sec)  Error Step Duration (sec)  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    Correct First Attempt  Incorrects  Hints  Corrects  \
# 0                    NaN         NaN    NaN       NaN
# 1                    NaN         NaN    NaN       NaN
# 2                    NaN         NaN    NaN       NaN
# 3                    NaN         NaN    NaN       NaN
# 4                    NaN         NaN    NaN       NaN
#
#                                     KC(Default) Opportunity(Default)
# 0                                           NaN                  NaN
# 1                       Changing axis intervals                   28
# 2  [SkillRule: Consolidate vars, no coeff; CLT]                   27
# 3                       Changing axis intervals                   65
# 4                                           NaN                  NaN

# %%
traindata['Step Name']
# Out:
# 0                    R1C1
# 1                    R1C2
# 2                    R3C1
# 3                    R3C2
# 4                    R4C1
# 5                    R5C1
# 6                    R6C1
# 7                    R7C2
# 8          ValidEquations
# 9           7/10*X = 1400
# 10           7X/10 = 1400
# 11                   R7C1
# 12                   R1C1
# 13                   R1C2
# 14                   R3C1
# 15                   R3C2
# 16                   R4C2
# 17                   R4C1
# 18                   R5C1
# 19                   R6C1
# 20                   R7C2
# 21         ValidEquations
# 22        3/5*X = 1200000
# 23         3X/5 = 1200000
# 24                   R7C1
# 25                   R1C1
# 26                   R1C2
# 27                   R3C1
# 28                   R3C2
# 29                   R4C1
#                ...
# 232714               R2C1
# 232715               R4C1
# 232716               R5C1
# 232717               R1C2
# 232718               R2C2
# 232719               R3C2
# 232720               R6C2
# 232721               R7C1
# 232722               R6C1
# 232723               R1C1
# 232724               R2C1
# 232725               R3C1
# 232726               R4C1
# 232727               R5C1
# 232728               R1C2
# 232729               R2C2
# 232730               R3C2
# 232731               R6C2
# 232732               R7C2
# 232733               R7C1
# 232734               R6C1
# 232735               R1C1
# 232736               R3C1
# 232737               R2C1
# 232738               R4C1
# 232739               R5C1
# 232740               R1C2
# 232741               R2C2
# 232742               R3C2
# 232743               R6C2
# Name: Step Name, Length: 232744, dtype: object

# %% [markdown]
# Let's begin asking some basic questions of the data
#
# ### How many students are interacting with the system?

# %%
# Take the column of anonimized student IDs and count the number of unique entries
print('Number of students: ', len(np.unique(traindata['Anon Student Id'])))
# Out:
# Number of students:  174

# %% [markdown]
# ### How long does it take a student to solve any problem step on average?

# %%
csd = traindata['Correct Step Duration (sec)']
csd.describe()
# Out:
# count    181599.000000
# mean         17.924024
# std          35.179534
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          17.000000
# max        1067.000000
# Name: Correct Step Duration (sec), dtype: float64

# %% [markdown]
# So ignoring all the students that did not solve a problem step correctly, the average duraction for any problem step was about 18 seconds.
#
# Let's histogram this data to see the distribution.

# %%
# %matplotlib inline
hist = plt.hist(np.array(csd.dropna()),bins=100,density=True,log=False,range=(0,100))
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Fraction')
plt.show()

# %%
counts, bins = hist[0], hist[1]
cdf = np.cumsum(counts)
plt.plot(bins[1::], cdf)
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Cumulative fraction')
plt.axis((0,100,0,1.0))
plt.show()

# %% [markdown]
# The histogram shows visually what mere statistics hints at. The distribution of students is heavily weighted towards those who are solving problems in under 20 seconds. The cumulative distribution function (CDF) shows that roughly 80% of successful students solve the problem within 20 seconds. After 40 seconds, 90% of successful students have finished the problem. Almost no students take longer than 80 seconds.

# %% [markdown]
# ### Completion time by problem
#
# OK, let's ask a slightly harder question: how are students doing problem by problem? The answer will take several parts.
#
# First, let's get the number of unique problems

# %%
# The unique identifier for each problem is the 'Problem Name'
problems = traindata['Problem Name']

# %%
# Get just the uniques
problems = np.unique(problems)
print('Number of unique problems: ', len(problems))
# Out:
# Number of unique problems:  1021

# %% [markdown]
# Then, let's compute which problems need the largest time on average.

# %%
pmedian_times = {}
for p in problems:
    pmedian_times[p] = traindata[traindata['Problem Name'] == p]['Correct Step Duration (sec)'].median()

# %%
import operator

# %%
sorted_times = sorted(pmedian_times.items(), key=operator.itemgetter(1), reverse=True)

# %%
print("The hardest top-5 problem and its average correct duration (sec).")
print(sorted_times[:5])

print("The earliest top-5 problem and its average correct duration (sec).")
print(sorted_times[len(sorted_times)-5:])
# Out:
# The hardest top-5 problem and its average correct duration (sec).
# [('JAN13C', 65.0), ('TRANSFORMN022', 32.0), ('EG-FACTOR45', 30.0), ('JAN13A', 25.5), ('LIT76A', 23.5)]
# The earliest top-5 problem and its average correct duration (sec).
# [('TRANSFORMG038', 1.5), ('TRANSFORMA045', 1.5), ('TRANSFORMA035', 1.25), ('TRANSFORMG039', 1.25), ('TRANSFORMN005', 1.0)]

# %% [markdown]
# Statistical results of problem difficulty

# %%
hist = plt.hist(np.array(list(pmedian_times.values())),bins=15,density=True,log=False,range=(0,25))
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Number')
plt.show()

# %% [markdown]
# If we take the time to correct answer as the difficulty of a problem, the histogram shows visually the difficulties of all the problems.

# %% [markdown]
# ### Conclusion
# There are many other interesting characteristic in this dataset.
# Like,
# * After some practices, students may become better at solving problems.
# * Same problem step for different students may request different knowledge components. Or for some problems, there is only one correct knowledge components
#
# These may be some things you need to take consider into for the feature engineering part. We leave them for you to explore deeper.

# %% [markdown]
# # Part 0: Initialize

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import random
pd.options.display.max_columns = None
pd.options.display.max_rows = 1000
from sklearn.model_selection import cross_val_score

# %%
traindata_origin = pd.read_csv('data/train.csv',sep = '\t')
testdata_origin = pd.read_csv('data/test.csv',sep = '\t')

# %% [markdown]
# # Part 1: Preprocess Data
# ## 1.1 Split Problem hierarchy
# First, we should split 2 columns and remove the origin one.
#
# #### Train Data

# %%
#temp_df = traindata_origin['Problem Hierarchy'].str.split(',')
temp_train = traindata_origin
temp_train['Problem Unit'] = traindata_origin['Problem Hierarchy'].str.split(',',1).str[0]
temp_train['Problem Section'] = traindata_origin['Problem Hierarchy'].str.split(',',1).str[1]

# %%
temp_train = temp_train.reindex(columns = ['Row','Anon Student Id','Problem Hierarchy','Problem Unit','Problem Section',\
                                    'Problem Name','Problem View','Step Name','Step Start Time',\
                                    'First Transaction Time','Correct Transaction Time',\
                                    'Step End Time','Step Duration (sec)','Correct Step Duration (sec)',\
                                    'Error Step Duration (sec)','Correct First Attempt','Incorrects',\
                                    'Hints','Corrects','KC(Default)','Opportunity(Default)'])

# %%
temp_train.head(1)
# Out:
#     Row Anon Student Id                Problem Hierarchy  Problem Unit  \
# 0  9938      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1  Unit CTA1_13
#
#       Problem Section Problem Name  Problem View Step Name  \
# 0   Section CTA1_13-1       PROP04             1      R1C1
#
#          Step Start Time First Transaction Time Correct Transaction Time  \
# 0  2005-09-09 12:23:34.0  2005-09-09 12:24:07.0    2005-09-09 12:24:07.0
#
#            Step End Time  Step Duration (sec)  Correct Step Duration (sec)  \
# 0  2005-09-09 12:24:07.0                 33.0                         33.0
#
#    Error Step Duration (sec)  Correct First Attempt  Incorrects  Hints  \
# 0                        NaN                      1           0      0
#
#    Corrects KC(Default) Opportunity(Default)
# 0         1         NaN                  NaN

# %%
traindata_pre = temp_train

# %% [markdown]
# #### Test Data

# %%
#temp_df = traindata_origin['Problem Hierarchy'].str.split(',')
temp_test = testdata_origin
temp_test['Problem Unit'] = testdata_origin['Problem Hierarchy'].str.split(',',1).str[0]
temp_test['Problem Section'] = testdata_origin['Problem Hierarchy'].str.split(',',1).str[1]

# %%
temp_test = temp_test.reindex(columns = ['Row','Anon Student Id','Problem Hierarchy','Problem Unit','Problem Section',\
                                    'Problem Name','Problem View','Step Name','Step Start Time',\
                                    'First Transaction Time','Correct Transaction Time',\
                                    'Step End Time','Step Duration (sec)','Correct Step Duration (sec)',\
                                    'Error Step Duration (sec)','Correct First Attempt','Incorrects',\
                                    'Hints','Corrects','KC(Default)','Opportunity(Default)'])

# %%
temp_test.head(1)
# Out:
#      Row Anon Student Id                Problem Hierarchy  Problem Unit  \
# 0  10039      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1  Unit CTA1_13
#
#       Problem Section Problem Name  Problem View     Step Name  \
# 0   Section CTA1_13-1       PROP01             1  2/300*X = 10
#
#    Step Start Time  First Transaction Time  Correct Transaction Time  \
# 0              NaN                     NaN                       NaN
#
#    Step End Time  Step Duration (sec)  Correct Step Duration (sec)  \
# 0            NaN                  NaN                          NaN
#
#    Error Step Duration (sec)  Correct First Attempt  Incorrects  Hints  \
# 0                        NaN                    NaN         NaN    NaN
#
#    Corrects KC(Default) Opportunity(Default)
# 0       NaN         NaN                  NaN

# %%
testdata_pre = temp_test

# %% [markdown]
# ## 1.2 Map string to Integer

# %%
temp_train = traindata_pre

# %%
temp_test = testdata_pre

# %% [markdown]
# ### 1. Anon Student Id

# %%
sids = list(set(temp_train['Anon Student Id']).union(set(temp_test['Anon Student Id'])))
sid_dict = {}
for index, sid in enumerate(sids):
    sid_dict[sid] = index
temp_train['Anon Student Id'] = temp_train['Anon Student Id'].apply(lambda x:sid_dict[x])
temp_test['Anon Student Id'] = temp_test['Anon Student Id'].apply(lambda x:sid_dict[x])
#     sid_dict[index] = sid
#     temp_train.loc[temp_train['Anon Student Id'] == sid, 'Anon Student Id'] = index
#     temp_test.loc[temp_test['Anon Student Id'] == sid, 'Anon Student Id'] = index

# %% [markdown]
# ### 2. Problem Hierarchy

# %%
prohies = list(set(temp_train['Problem Hierarchy']).union(set(temp_test['Problem Hierarchy'])))
prohie_dict = {}
for index, prohie in enumerate(prohies):
    prohie_dict[prohie] = index
temp_train['Problem Hierarchy'] = temp_train['Problem Hierarchy'].apply(lambda x:prohie_dict[x])
temp_test['Problem Hierarchy'] = temp_test['Problem Hierarchy'].apply(lambda x:prohie_dict[x])
#     prohie_dict[index] = prohie
#     temp_train.loc[temp_train['Problem Hierarchy'] == prohie, 'Problem Hierarchy'] = index
#     temp_test.loc[temp_test['Problem Hierarchy'] == prohie, 'Problem Hierarchy'] = index

# %% [markdown]
# ### 3. Problem Unit

# %%
prounis = list(set(temp_train['Problem Unit']).union(set(temp_test['Problem Unit'])))
prouni_dict = {}
for index, prouni in enumerate(prounis):
    prouni_dict[prouni] = index
temp_train['Problem Unit'] = temp_train['Problem Unit'].apply(lambda x:prouni_dict[x])
temp_test['Problem Unit'] = temp_test['Problem Unit'].apply(lambda x:prouni_dict[x])
#     prouni_dict[index] = prouni
#     temp_train.loc[temp_train['Problem Unit'] == prouni, 'Problem Unit'] = index
#     temp_test.loc[temp_test['Problem Unit'] == prouni, 'Problem Unit'] = index

# %% [markdown]
# ### 4. Problem Section

# %%
prosecs = list(set(temp_train['Problem Section']).union(set(temp_test['Problem Section'])))
prosec_dict = {}
for index, prosec in enumerate(prosecs):
    prosec_dict[prosec] = index
temp_train['Problem Section'] = temp_train['Problem Section'].apply(lambda x:prosec_dict[x])
temp_test['Problem Section'] = temp_test['Problem Section'].apply(lambda x:prosec_dict[x])
#     prosec_dict[index] = prosec
#     temp_train.loc[temp_train['Problem Section'] == prosec, 'Problem Section'] = index
#     temp_test.loc[temp_test['Problem Section'] == prosec, 'Problem Section'] = index

# %% [markdown]
# ### 5. Problem Name

# %%
pronams = list(set(temp_train['Problem Name']).union(set(temp_test['Problem Name'])))
pronam_dict = {}
for index,pronam in enumerate(pronams):
    pronam_dict[pronam] = index
temp_train['Problem Name'] = temp_train['Problem Name'].apply(lambda x:pronam_dict[x])
temp_test['Problem Name'] = temp_test['Problem Name'].apply(lambda x:pronam_dict[x])
#     pronam_dict[index] = pronam
#     temp_train.loc[temp_train['Problem Name'] == pronam, 'Problem Name'] = index
#     temp_test.loc[temp_test['Problem Name'] == pronam, 'Problem Name'] = index

# %% [markdown]
# ### 6. Step Name

# %%
stenams = list(set(temp_train['Step Name']).union(set(temp_test['Step Name'])))
stenam_dict = {}
for index,stenam in enumerate(stenams):
    stenam_dict[stenam] = index
temp_train['Step Name'] = temp_train['Step Name'].apply(lambda x:stenam_dict[x])
temp_test['Step Name'] = temp_test['Step Name'].apply(lambda x:stenam_dict[x])

# %%
temp_train.to_csv('train_cor.csv',sep='\t',index = False)
temp_test.to_csv('test_cor.csv',sep='\t', index = False)

# %% [markdown]
# ### Correlation

# %%
x_df = pd.read_csv('train_pre.csv',sep = '\t')

# %%
import matplotlib.pyplot as plt
import pandas
import numpy

names = ['Personal CFAR', 'Problem CFAR','Anon Student Id','Problem Unit', 'Problem Section', 'Step Name', 'Problem Name', 'Problem View', 'Correct First Attempt', 'KC_num', 'Step CFAR', 'KC CFAR']
correlations = x_df[names].corr()
# plot correlation matrix
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(222)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,len(names),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.savefig('./1.jpg')
plt.show()
